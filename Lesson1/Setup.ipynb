# %% [markdown]
# # 1. Installation and setup

# %% [markdown]
# Explain why we will use these tools, what they are, what they will help us with

# %% [markdown]
# ## 1.1. Conda

# %% [markdown]
# Package manager
# bundles libraries
# helps setting an environment for us

# %% [markdown]
# ## 1.2. Jupyter

# %% [markdown]
# Cuts the need to go terminal fu and run python vanilla style

# %% [markdown]
# ## 1.3. Slack

# %% [markdown]
# Will be our main place of communication, you can issue any question here with @pedroallenrevez

# %% [markdown]
# # 2. Hello World!

# %%
print("Welcome to MEEC's Python Symposium")
# Out:
# Welcome to MEEC's Python Symposium

# %% [markdown]
# # 3. A primer on learning anything

# %% [markdown]
# So that we can learn effectively, some things to keep in mind

# %% [markdown]
# ## 3.1. A drowning man can't swim

# %% [markdown]
# a lot of information at the same time will ddos your brain

# %% [markdown]
# ## 3.2. Intellectual Honesty - there are no stupid questions

# %% [markdown]
# all questions should be asked, to me, your friends, or anyone.
# if you dont want to ask them in class, please ask in slack and I will help you

# %% [markdown]
# ## 3.3. Motivate your decision to learn

# %% [markdown]
# The most important driving force in learning is WHY you're doing it.
# It also dictates how hard it is to keep going at in.

# %% [markdown]
# # 4. Overview of programming languages

# %% [markdown]
# There are two main types of languages classified in two boxes.
# There are more, like OOP, but I just classify this as sequential.

# %% [markdown]
# ## 4.1. Functional

# %% [markdown]
# Give haskell example

# %% [markdown]
# ## 4.2. Sequential

# %% [markdown]
# Python example
