# %%
from IPython.core.display import display, HTML
display(HTML("<style>"
    + "#notebook { padding-top:0px !important; } " 
    + ".container { width:100% !important; } "
    + ".end_space { min-height:0px !important; } "
    + ".CodeMirror pre {font-family: Monaco; font-size: 9pt;}"
    + "div.text_cell_render {font-family: 'Roboto'; font-size: 11pt;}"
    + "</style>"))
from functools import reduce

# %% [markdown]
# # 1. Exercises
#
# These exercises are suposed to reinforce what you learn on the `Basics` module.
#
# This will cover very simple functions implemented by Python already, so you can comprehend what is going on behind Python.
#
# The objective of these exercises is making sure that you can express some thoughts into a programming language (in our workshop, this is Python).
#
# <img src="https://www.i-programmer.info/images/stories/prof/iprogrammer/ProgramPower/logictime.jpg">

# %% [markdown]
# # 2. Questions
#
# Throughout the questions you will find a couple of `REPLACE_ME` variables and lines.
#
# These should be **replaced** with your code instead.
#
# ---
#
# The **solutions** for the problem will be discussed in class.
#
# Please try to **take note** of what parts of the exercise was **most difficult** to you,
# so we can try to tackle these problems while solving them together.

# %% [markdown]
# ## 2.1. Finding the minimum and maximum
#
# You function should replicate the results of the `min()` and `max()` functions.

# %%
def my_min(REPLACE_ME):
    # CODE GOES HERE
    return REPLACE_ME

my_result = my_min([1,2,5,8,255,54])
python_result = min([1,2,5,8,255,54])
assert my_result == python_result , \
f"Seems that your function is wrong. my_min should be returning {python_result} and is returning {my_result}"

# %%
def my_max(REPLACE_ME):
    CODE GOES HERE
    return REPLACE_ME

my_result = my_max([1,2,5,8,255,54])
python_result = max([1,2,5,8,255,54])
assert my_result == python_result , \
f"Seems that your function is wrong. my_max should be returning {python_result} and is returning {my_result}"

# %% [markdown]
# ## 2.2. Finding the length of a string and a list
#
# In this exercise you should find the length of a list or a string.
#
# Your function should **only** take both **lists** and **strings**.
#
# Implement this with a **while**.

# %%
def my_len(REPLACE_ME):
    if not isinstance(REPLACE_ME, list):
        print(f"Received variable {REPLACE_ME} is not a list!")
    if not isinstance(REPLACE_ME, str):
        print(f"Received variable {REPLACE_ME} is not a string!")
    # CODE GOES HERE
    return REPLACE_ME

my_result = my_len([1,2,5,8,255,54])
python_result = len([1,2,5,8,255,54])
assert my_result == python_result , \
f"Seems that your function is wrong. my_len should be returning {python_result} and is returning {my_result}"

# %% [markdown]
# ### 2.2.1. Extra question
#
# Try to explain what this piece of code is doing:
#
# ```python
# if not isinstance(REPLACE_ME, list):
#     print(f"Received variable {REPLACE_ME} is not a list!")
# ```

# %% [markdown]
# Answer here!

# %% [markdown]
# ## 2.3. Reversing a list or string
#
# Here, we will implement a function to reverse a list or string (since these are very similar inside Python!)
#
# Your function should **only** receive **lists** or **strings**.

# %%
def my_reverse(REPLACE_ME):
    if not isinstance(REPLACE_ME, list):
        print(f"Received variable {REPLACE_ME} is not a list!")
    if not isinstance(REPLACE_ME, str):
        print(f"Received variable {REPLACE_ME} is not a string!")
    # CODE GOES HERE
    return REPLACE_ME

my_result = my_reverse([1,2,5,8,255,54])
python_result = [1,2,5,8,255,54][::-1]
assert my_result == python_result , \
f"Seems that your function is wrong. my_reverse should be returning {python_result} and is returning {my_result}"

# %% [markdown]
# # 2.4. Multiplying all numbers in a list
#
# In this exercise, you are supposed to multiply all the numbers you find in a list.
#
# Remember, `a *= 2` is the same as `a = a * 2`.

# %%
def my_multiplier(REPLACE_ME):
    if not isinstance(REPLACE_ME, list):
        print(f"Received variable {REPLACE_ME} is not a list!")
    if not isinstance(REPLACE_ME, str):
        print(f"Received variable {REPLACE_ME} is not a string!")
    # CODE GOES HERE
    return REPLACE_ME

my_result = my_multiplier([1,2,5,8,255,54])
python_result = reduce(lambda x, y: x * y, [1,2,5,8,255,54])
assert my_result == python_result , \
f"Seems that your function is wrong. my_multiplier should be returning {python_result} and is returning {my_result}"

# %% [markdown]
# # 3. The Euler Project
#
# Leohnard Euler | Euler's Formula
# - | -
# <img src="https://micro.magnet.fsu.edu/optics/timeline/people/antiqueimages/euler.jpg"> | <img src="https://i.ytimg.com/vi/Px7vI36WKqg/maxresdefault.jpg" width="600">

# %% [markdown]
# ## 3.1. Multiples of 3 and 5
#
# If we list all the natural numbers below 10 that are multiples of 3 or 5, we get 3, 5, 6 and 9. The sum of these multiples is 23.
#
# Find the sum of all the multiples of 3 or 5 below 1000.
#
# Suggestions:
# 1. Do a function that **verifies** (returns either True or False) if a number is multiple of 3
# 2. Do the same for multiples of 5
# 3. **Iterate** until 1000 (remember you can use **range** for this!)
# 4. Use the functions made in 1. and 2. and find the sum
# 5. ...
# 6. \$\$\$

# %%
# Code goes here
